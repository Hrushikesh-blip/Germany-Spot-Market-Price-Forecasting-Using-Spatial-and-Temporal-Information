# %%
# A python library that allows to work with multidimensional arrays and mathematical functions.
import numpy as np
# A python library that is widely used for reading, processing and analyzind data.
import pandas as pd
# They imported the pickle and csv files to work with.
import pickle, csv
# It used to interact with the operating system, and its path. 
import os

# Keras is a high-level API used to build deep learning models. Keras enables model creation with sequential and functional APIs.
from keras.models import Sequential, load_model, Model
# These are the layers of the model. LSTM is a type of reccurent neural network. 
# Dense is a fully connected layer. Others are different types of neural network layers.
from keras.layers import LSTM, Dense, Dropout, Input, concatenate, Flatten, Reshape
# This following import uses to reduce overfitting problems by limiting weights.
from keras import regularizers

# ModelCheckPoint records the model's weights at regular intervals during training. 
# EarlyStopping stops training if a specific metric does not improve over a specified period of time.
from keras.callbacks import ModelCheckpoint, EarlyStopping
# MeanSquaredError provides the mean square error measurement.
# RootMeanSquared Error measures the root mean square error.
# Adam is a widely used gradient descent optimization algorithm.
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.sequence import TimeseriesGenerator
import tensorflow.keras.backend as K

# Importing pyplot module from the matplotlib library.
# This module is used to perform data visualization. 
# With abbreviation 'plt' this module can be accessable. 
from matplotlib import pyplot as plt
# Importing the style module from the matplotlib library. 
# This module is used to determine the style of graphics and drawings.
from matplotlib import style
# Importing StandardScaler and MinMaxScaler classes of the preprocessing module from the sklearn library.
# These classes are used to scale and standardize data properties.
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Importing the train_test_split function of the model_selection module from the sklearn library.
# This function is used to separate the data set into training and testing sets.
from sklearn.model_selection import train_test_split
#  Seaborn is a Python library used for data visualization. 
# Similar to Matplotlib, it is used to create more effective and attractive visualizations.
import seaborn as sns

# %%
# This block of code in the following reads data from a file named 'PowerPrice.csv', 
# edits the datetime column, and creates a data frame as a result.
# Such operations are performed during the data preprocessing stage and
# ensure that the data set is ready for analysis.

# %%
# Read a CSV file named and assign this data to a Pandas data frame (DateFrame).
# The name of the data frame is df_powerprice.
df_powerprice = pd.read_csv("data/PowerPrice.csv")
# convert the 'Time' column into datatime objects. The data type of the column is converted to date-time
# format with the pd.to_datetime function.
# infer_datetime_format = True parameter allows the date format to be determined automatically.
df_powerprice["Time"] = pd.to_datetime(df_powerprice["Time"], infer_datetime_format=True)
# In the following row, 'Time' column is removed from the data frame. 
# This column will no longer be present in the dataframe.
df_powerprice = df_powerprice.drop(columns=["Time"])
# Print the data frame obtained as a result of the above rows to the screen.
df_powerprice
# Out:
#        DayAhead   Spot   REBAP
# 0       2.83200  3.688  -4.566
# 1       2.37575  4.245 -13.964
# 2       1.91950  3.161   0.345
# 3       1.46325  1.664   3.048
# 4       1.00700  3.110  -6.679
# ...         ...    ...     ...
# 35035   3.77625  3.342   4.856
# 35036   3.73900  4.425   8.561
# 35037   3.70175  2.473   6.076
# 35038   3.66450  3.241  11.797
# 35039   3.62725  3.271  16.040
#
# [35040 rows x 3 columns]

# %%
# This bloc of the code processes files with the '.pickle' extebsion in the 'data/Spatial' directory and adds them 
# to the list of datasets with a certain shape. It prints the names of files whose shapes do not match and 
# the expected shape to the screen. This process is done to examine the existing files and select the appropriate ones.#

# %%
# Creating an empty list datasets. 
# This list will be used to store processed datasets.
datasets = []
# Starting a loop to process the files in the 'data/Spatial' directory.
# os.listdir() function returns a list of files located in the specified directory.
for filename in os.listdir("data/Spatial"):
    # If statement checks the file is '.pickle', then process will be started.
    # The .endswith() method checks whether the last characters in a string match the specified pattern.
    if filename.endswith(".pickle"):
        # Starting the file reading process.
        # The file is opened in 'rb' mode (binary reading).
        with open(os.path.join("data/Spatial", filename), "rb") as file:
            # The data in the file is loaded using the pickle module. It is loaded data stored in pickle format.
            datasets.append(pickle.load(file))
            print(filename)
# The processed datasets in the datasets list are combine (row-wise) on the axis = 0.
data = np.concatenate(datasets, axis=0)
# The combined dataset is transposed. This process converts the dataset's column into rows and rows into columns.
data = data.T
# The data converted into a DataFrame. This is used to process and analyze data more easily.
df_spatial = pd.DataFrame(data)
# Out:
# biogas_kw_2019.pickle
# brown_coal_kw_2019.pickle
# completed_solar_kw_2019.pickle
# completed_wind_onshore_kw_2019.pickle
# demand_kw_2019.pickle
# hard_coal_kw_2019.pickle
# nuclear_kw_2019.pickle
# oil_kw_2019.pickle
# water_laufwasser_kw_2019.pickle
# water_pumpspeicher_PB_kw_2019.pickle
# water_pumpspeicher_TB_kw_2019.pickle
# water_speicherwasser_kw_2019.pickle
# wind_offshore_kw_2019.pickle

# %%
# The following code is used to scale data. The scaling process ensures that the data is brought within a certain range.

# %%
# Min-Max scaling scales data by converting it to a specific range [0, 1]. 
# This makes it easier to compare data across different features.
scaler_spatial = MinMaxScaler()
df_spatial_scaled = scaler_spatial.fit_transform(df_spatial)

scaler_powerprice = MinMaxScaler()
df_powerprice_scaled = scaler_powerprice.fit_transform(df_powerprice)

# %%
df_powerprice_scaled.shape, df_spatial_scaled.shape
# Out:
# ((35040, 3), (35040, 1300))

# %%
# It performs reshaping operations to make the data compatible with the input form of the train_set_split function and model.

# %%
# Reshape the data to fit the model input shape
input_1_data = df_spatial_scaled.reshape((-1, 6, 1300))
input_2_data = df_powerprice_scaled[:, [1]].reshape((-1, 6, 1))
output_data = df_powerprice_scaled[:,1].reshape((-1, 6, 1))

# %%
# check the removed REBAP
input_2_data.shape, input_1_data.shape, output_data.shape
# Out:
# ((5840, 6, 1), (5840, 6, 1300), (5840, 6, 1))

# %%
# Split the data into train, validation and test sets
input_1_train, input_1_test, input_2_train, input_2_test, output_train, output_test = train_test_split(
    input_1_data, input_2_data, output_data, test_size=0.2, random_state=30)
input_1_train, input_1_val, input_2_train, input_2_val, output_train, output_val = train_test_split(
    input_1_train, input_2_train, output_train, test_size=0.3, random_state=30)

# %%
# In the code below, a deep learning model with two different inputs is created.
# This model includes fully connected layers, dropout layers, LSTM layers and an output layer.
# This architecture has been chosen to suit the characteristics of spatial and temporal datasets.

# %%
# The input function defines the input data format of the model.There are two inputs are defines as shape (6, 1300) and (6,1).
# The first input (spatial_input) is determined to have 6 time periods and 1300 features columns.
# The second input (powerprice_input) is determined to have 6 time frames and 1 feature column.
spatial_input = Input(shape=(6, 1300,))
powerprice_input = Input(shape=(6, 1,))
# The dense layer creates a fully connected layer.
# There are 64 neurons in this layer and the ReLU activation function is used.
fcnn_layer = Dense(64, activation="relu")(spatial_input)
# The dropout layer is used to prevent overfitting.
# In this case, randomly selected neurons with probability 0.2 are disabled.
fcnn_layer = Dropout(0.2)(fcnn_layer)
# Another fully connected layer is added.
# This time 32 neurons are used and the ReLU activation is used again.
fcnn_layer = Dense(32, activation="relu")(fcnn_layer)
# Another dropout layer.
fcnn_layer = Dropout(0.2)(fcnn_layer)
# The last fully connected layer is created.
# This time, 8 nmeurons and the ReLU activation function is used.
fcnn_output = Dense(8, activation="relu")(fcnn_layer)
# with the concat_layer the two outputs of two different layers are concatenated. 
concat_layer = concatenate([fcnn_output, powerprice_input])
# The data reshaped in specific needs.
reshape_layer = Reshape((concat_layer.shape[1], concat_layer.shape[2]))(concat_layer)
# Here, the shape of the output is set to concat_layer.shape[1] and concat_layer.shape[2].
lstm_layer = LSTM(10, activation="relu")(reshape_layer)
output_layer = Dense(1)(lstm_layer)
model = Model(inputs=[spatial_input, powerprice_input], outputs=output_layer)

# %%
# Compile the model.
# A model object is created by determining the inputs and outputs of the model.
# The input and output layers are determined with the inputs and outputs parameters.
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
concat_layer.shape
# Out:
# TensorShape([None, 6, 9])

# %%
# EarlyStopping callback is created to enable early stopping during the trainin process.
# This recall monitors changes in validation loass and stops training if there is no improvement
# for a certain patience period. 
# The restore_best_weights = true parameters ensures that the best weights are stored.
es = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)

# A ModelCheckpoint callback to record the weights at which the model performs best during training. 
# This callback will save the best model with the specified file path and name.
cp = ModelCheckpoint(filepath="model_spot/forecasting-TRY/", 
                      save_best_only=True,
                      monitor='val_loss', 
                      mode='min', 
                      save_weights_only=False, 
                      verbose=1)

# %%
# The line is basicly the model training is done with input_1_train, input_2_train and output_train.
# The batch_size = 5 parameter specifies the size of the data batch to be used in each training step.
# The epochs = 1000 parameter specifies how many epochs will be trained in total.
# The validation_data = (input_1_val, input_2_val) parameter enables the validation set to be used.

history = model.fit([input_1_train, input_2_train], output_train, 
                    epochs=1000,
                    batch_size=5,
                    validation_data=([input_1_val, input_2_val], output_val),
                    callbacks=[cp, es])
# Out:
# Epoch 1/1000
# 641/654 [============================>.] - ETA: 0s - loss: 0.0051 - root_mean_squared_error: 0.0713
# Epoch 1: val_loss improved from inf to 0.00069, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 7s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 6.8877e-04 - val_root_mean_squared_error: 0.0262
# Epoch 2/1000
# 632/654 [===========================>..] - ETA: 0s - loss: 0.0016 - root_mean_squared_error: 0.0397
# Epoch 2: val_loss improved from 0.00069 to 0.00060, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 5.9933e-04 - val_root_mean_squared_error: 0.0245
# Epoch 3/1000
# 642/654 [============================>.] - ETA: 0s - loss: 0.0011 - root_mean_squared_error: 0.0327
# Epoch 3: val_loss did not improve from 0.00060
# 654/654 [==============================] - 2s 3ms/step - loss: 0.0011 - root_mean_squared_error: 0.0326 - val_loss: 9.3251e-04 - val_root_mean_squared_error: 0.0305
# Epoch 4/1000
# 621/654 [===========================>..] - ETA: 0s - loss: 7.4099e-04 - root_mean_squared_error: 0.0272
# Epoch 4: val_loss improved from 0.00060 to 0.00050, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 7.3323e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9749e-04 - val_root_mean_squared_error: 0.0223
# Epoch 5/1000
# 650/654 [============================>.] - ETA: 0s - loss: 6.0136e-04 - root_mean_squared_error: 0.0245
# Epoch 5: val_loss improved from 0.00050 to 0.00042, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 6.0049e-04 - root_mean_squared_error: 0.0245 - val_loss: 4.1639e-04 - val_root_mean_squared_error: 0.0204
# Epoch 6/1000
# 651/654 [============================>.] - ETA: 0s - loss: 5.4006e-04 - root_mean_squared_error: 0.0232
# Epoch 6: val_loss improved from 0.00042 to 0.00034, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 5.4110e-04 - root_mean_squared_error: 0.0233 - val_loss: 3.4064e-04 - val_root_mean_squared_error: 0.0185
# Epoch 7/1000
# 631/654 [===========================>..] - ETA: 0s - loss: 5.2253e-04 - root_mean_squared_error: 0.0229
# Epoch 7: val_loss did not improve from 0.00034
# 654/654 [==============================] - 4s 6ms/step - loss: 5.1863e-04 - root_mean_squared_error: 0.0228 - val_loss: 3.4962e-04 - val_root_mean_squared_error: 0.0187
# Epoch 8/1000
# 636/654 [============================>.] - ETA: 0s - loss: 4.7856e-04 - root_mean_squared_error: 0.0219
# Epoch 8: val_loss improved from 0.00034 to 0.00032, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 4.7996e-04 - root_mean_squared_error: 0.0219 - val_loss: 3.1960e-04 - val_root_mean_squared_error: 0.0179
# Epoch 9/1000
# 629/654 [===========================>..] - ETA: 0s - loss: 4.6276e-04 - root_mean_squared_error: 0.0215
# Epoch 9: val_loss did not improve from 0.00032
# 654/654 [==============================] - 2s 4ms/step - loss: 4.6029e-04 - root_mean_squared_error: 0.0215 - val_loss: 4.2208e-04 - val_root_mean_squared_error: 0.0205
# Epoch 10/1000
# 625/654 [===========================>..] - ETA: 0s - loss: 4.4758e-04 - root_mean_squared_error: 0.0212
# Epoch 10: val_loss did not improve from 0.00032
# 654/654 [==============================] - 2s 3ms/step - loss: 4.3911e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.6705e-04 - val_root_mean_squared_error: 0.0192
# Epoch 11/1000
# 642/654 [============================>.] - ETA: 0s - loss: 4.1087e-04 - root_mean_squared_error: 0.0203
# Epoch 11: val_loss did not improve from 0.00032
# 654/654 [==============================] - 2s 3ms/step - loss: 4.0926e-04 - root_mean_squared_error: 0.0202 - val_loss: 3.4458e-04 - val_root_mean_squared_error: 0.0186
# Epoch 12/1000
# 635/654 [============================>.] - ETA: 0s - loss: 4.0457e-04 - root_mean_squared_error: 0.0201
# Epoch 12: val_loss did not improve from 0.00032
# 654/654 [==============================] - 2s 3ms/step - loss: 4.0017e-04 - root_mean_squared_error: 0.0200 - val_loss: 3.2946e-04 - val_root_mean_squared_error: 0.0182
# Epoch 13/1000
# 647/654 [============================>.] - ETA: 0s - loss: 3.8277e-04 - root_mean_squared_error: 0.0196
# Epoch 13: val_loss improved from 0.00032 to 0.00030, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 3.8285e-04 - root_mean_squared_error: 0.0196 - val_loss: 3.0123e-04 - val_root_mean_squared_error: 0.0174
# Epoch 14/1000
# 644/654 [============================>.] - ETA: 0s - loss: 3.7103e-04 - root_mean_squared_error: 0.0193
# Epoch 14: val_loss did not improve from 0.00030
# 654/654 [==============================] - 3s 5ms/step - loss: 3.6925e-04 - root_mean_squared_error: 0.0192 - val_loss: 3.0453e-04 - val_root_mean_squared_error: 0.0175
# Epoch 15/1000
# 646/654 [============================>.] - ETA: 0s - loss: 3.5804e-04 - root_mean_squared_error: 0.0189
# Epoch 15: val_loss improved from 0.00030 to 0.00027, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 3.5648e-04 - root_mean_squared_error: 0.0189 - val_loss: 2.7454e-04 - val_root_mean_squared_error: 0.0166
# Epoch 16/1000
# 645/654 [============================>.] - ETA: 0s - loss: 3.4439e-04 - root_mean_squared_error: 0.0186
# Epoch 16: val_loss did not improve from 0.00027
# 654/654 [==============================] - 2s 3ms/step - loss: 3.4316e-04 - root_mean_squared_error: 0.0185 - val_loss: 2.8540e-04 - val_root_mean_squared_error: 0.0169
# Epoch 17/1000
# 640/654 [============================>.] - ETA: 0s - loss: 3.3012e-04 - root_mean_squared_error: 0.0182
# Epoch 17: val_loss did not improve from 0.00027
# 654/654 [==============================] - 2s 4ms/step - loss: 3.2886e-04 - root_mean_squared_error: 0.0181 - val_loss: 3.1076e-04 - val_root_mean_squared_error: 0.0176
# Epoch 18/1000
# 649/654 [============================>.] - ETA: 0s - loss: 3.2498e-04 - root_mean_squared_error: 0.0180
# Epoch 18: val_loss did not improve from 0.00027
# 654/654 [==============================] - 3s 5ms/step - loss: 3.2479e-04 - root_mean_squared_error: 0.0180 - val_loss: 2.8296e-04 - val_root_mean_squared_error: 0.0168
# Epoch 19/1000
# 642/654 [============================>.] - ETA: 0s - loss: 3.1428e-04 - root_mean_squared_error: 0.0177
# Epoch 19: val_loss improved from 0.00027 to 0.00026, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 3.1261e-04 - root_mean_squared_error: 0.0177 - val_loss: 2.6435e-04 - val_root_mean_squared_error: 0.0163
# Epoch 20/1000
# 645/654 [============================>.] - ETA: 0s - loss: 3.0782e-04 - root_mean_squared_error: 0.0175
# Epoch 20: val_loss improved from 0.00026 to 0.00026, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 3.0665e-04 - root_mean_squared_error: 0.0175 - val_loss: 2.5954e-04 - val_root_mean_squared_error: 0.0161
# Epoch 21/1000
# 641/654 [============================>.] - ETA: 0s - loss: 2.9246e-04 - root_mean_squared_error: 0.0171
# Epoch 21: val_loss improved from 0.00026 to 0.00024, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 2.8955e-04 - root_mean_squared_error: 0.0170 - val_loss: 2.4212e-04 - val_root_mean_squared_error: 0.0156
# Epoch 22/1000
# 642/654 [============================>.] - ETA: 0s - loss: 2.8975e-04 - root_mean_squared_error: 0.0170
# Epoch 22: val_loss improved from 0.00024 to 0.00024, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 2.8897e-04 - root_mean_squared_error: 0.0170 - val_loss: 2.4045e-04 - val_root_mean_squared_error: 0.0155
# Epoch 23/1000
# 635/654 [============================>.] - ETA: 0s - loss: 2.5390e-04 - root_mean_squared_error: 0.0159
# Epoch 23: val_loss improved from 0.00024 to 0.00023, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 2.7763e-04 - root_mean_squared_error: 0.0167 - val_loss: 2.3335e-04 - val_root_mean_squared_error: 0.0153
# Epoch 24/1000
# 653/654 [============================>.] - ETA: 0s - loss: 2.7539e-04 - root_mean_squared_error: 0.0166
# Epoch 24: val_loss did not improve from 0.00023
# 654/654 [==============================] - 2s 4ms/step - loss: 2.7528e-04 - root_mean_squared_error: 0.0166 - val_loss: 2.5490e-04 - val_root_mean_squared_error: 0.0160
# Epoch 25/1000
# 654/654 [==============================] - ETA: 0s - loss: 2.7906e-04 - root_mean_squared_error: 0.0167
# Epoch 25: val_loss did not improve from 0.00023
# 654/654 [==============================] - 2s 3ms/step - loss: 2.7906e-04 - root_mean_squared_error: 0.0167 - val_loss: 2.7972e-04 - val_root_mean_squared_error: 0.0167
# Epoch 26/1000
# 641/654 [============================>.] - ETA: 0s - loss: 2.5268e-04 - root_mean_squared_error: 0.0159
# Epoch 26: val_loss improved from 0.00023 to 0.00023, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 2.5050e-04 - root_mean_squared_error: 0.0158 - val_loss: 2.2781e-04 - val_root_mean_squared_error: 0.0151
# Epoch 27/1000
# 631/654 [===========================>..] - ETA: 0s - loss: 2.4487e-04 - root_mean_squared_error: 0.0156
# Epoch 27: val_loss did not improve from 0.00023
# 654/654 [==============================] - 2s 3ms/step - loss: 2.4646e-04 - root_mean_squared_error: 0.0157 - val_loss: 2.5132e-04 - val_root_mean_squared_error: 0.0159
# Epoch 28/1000
# 650/654 [============================>.] - ETA: 0s - loss: 2.3891e-04 - root_mean_squared_error: 0.0155
# Epoch 28: val_loss improved from 0.00023 to 0.00019, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 2.3867e-04 - root_mean_squared_error: 0.0154 - val_loss: 1.9451e-04 - val_root_mean_squared_error: 0.0139
# Epoch 29/1000
# 648/654 [============================>.] - ETA: 0s - loss: 2.2271e-04 - root_mean_squared_error: 0.0149
# Epoch 29: val_loss did not improve from 0.00019
# 654/654 [==============================] - 3s 4ms/step - loss: 2.2208e-04 - root_mean_squared_error: 0.0149 - val_loss: 2.3959e-04 - val_root_mean_squared_error: 0.0155
# Epoch 30/1000
# 649/654 [============================>.] - ETA: 0s - loss: 2.1604e-04 - root_mean_squared_error: 0.0147
# Epoch 30: val_loss improved from 0.00019 to 0.00019, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 2.1535e-04 - root_mean_squared_error: 0.0147 - val_loss: 1.8660e-04 - val_root_mean_squared_error: 0.0137
# Epoch 31/1000
# 643/654 [============================>.] - ETA: 0s - loss: 2.0383e-04 - root_mean_squared_error: 0.0143
# Epoch 31: val_loss did not improve from 0.00019
# 654/654 [==============================] - 3s 4ms/step - loss: 2.0365e-04 - root_mean_squared_error: 0.0143 - val_loss: 1.8751e-04 - val_root_mean_squared_error: 0.0137
# Epoch 32/1000
# 623/654 [===========================>..] - ETA: 0s - loss: 1.9680e-04 - root_mean_squared_error: 0.0140
# Epoch 32: val_loss improved from 0.00019 to 0.00017, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 1.9512e-04 - root_mean_squared_error: 0.0140 - val_loss: 1.7378e-04 - val_root_mean_squared_error: 0.0132
# Epoch 33/1000
# 652/654 [============================>.] - ETA: 0s - loss: 1.9626e-04 - root_mean_squared_error: 0.0140
# Epoch 33: val_loss did not improve from 0.00017
# 654/654 [==============================] - 2s 3ms/step - loss: 1.9673e-04 - root_mean_squared_error: 0.0140 - val_loss: 1.7902e-04 - val_root_mean_squared_error: 0.0134
# Epoch 34/1000
# 650/654 [============================>.] - ETA: 0s - loss: 1.7989e-04 - root_mean_squared_error: 0.0134
# Epoch 34: val_loss improved from 0.00017 to 0.00017, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.7931e-04 - root_mean_squared_error: 0.0134 - val_loss: 1.6645e-04 - val_root_mean_squared_error: 0.0129
# Epoch 35/1000
# 635/654 [============================>.] - ETA: 0s - loss: 1.7495e-04 - root_mean_squared_error: 0.0132
# Epoch 35: val_loss did not improve from 0.00017
# 654/654 [==============================] - 2s 4ms/step - loss: 1.7429e-04 - root_mean_squared_error: 0.0132 - val_loss: 1.7470e-04 - val_root_mean_squared_error: 0.0132
# Epoch 36/1000
# 644/654 [============================>.] - ETA: 0s - loss: 1.7368e-04 - root_mean_squared_error: 0.0132
# Epoch 36: val_loss improved from 0.00017 to 0.00015, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.7315e-04 - root_mean_squared_error: 0.0132 - val_loss: 1.4586e-04 - val_root_mean_squared_error: 0.0121
# Epoch 37/1000
# 635/654 [============================>.] - ETA: 0s - loss: 1.6136e-04 - root_mean_squared_error: 0.0127
# Epoch 37: val_loss improved from 0.00015 to 0.00014, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.6052e-04 - root_mean_squared_error: 0.0127 - val_loss: 1.4147e-04 - val_root_mean_squared_error: 0.0119
# Epoch 38/1000
# 635/654 [============================>.] - ETA: 0s - loss: 1.5516e-04 - root_mean_squared_error: 0.0125
# Epoch 38: val_loss did not improve from 0.00014
# 654/654 [==============================] - 2s 3ms/step - loss: 1.5418e-04 - root_mean_squared_error: 0.0124 - val_loss: 1.4452e-04 - val_root_mean_squared_error: 0.0120
# Epoch 39/1000
# 642/654 [============================>.] - ETA: 0s - loss: 1.4968e-04 - root_mean_squared_error: 0.0122
# Epoch 39: val_loss did not improve from 0.00014
# 654/654 [==============================] - 2s 3ms/step - loss: 1.4900e-04 - root_mean_squared_error: 0.0122 - val_loss: 1.4353e-04 - val_root_mean_squared_error: 0.0120
# Epoch 40/1000
# 647/654 [============================>.] - ETA: 0s - loss: 1.4168e-04 - root_mean_squared_error: 0.0119
# Epoch 40: val_loss improved from 0.00014 to 0.00013, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 1.4124e-04 - root_mean_squared_error: 0.0119 - val_loss: 1.3263e-04 - val_root_mean_squared_error: 0.0115
# Epoch 41/1000
# 646/654 [============================>.] - ETA: 0s - loss: 1.3533e-04 - root_mean_squared_error: 0.0116
# Epoch 41: val_loss improved from 0.00013 to 0.00013, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.3486e-04 - root_mean_squared_error: 0.0116 - val_loss: 1.2886e-04 - val_root_mean_squared_error: 0.0114
# Epoch 42/1000
# 651/654 [============================>.] - ETA: 0s - loss: 1.3800e-04 - root_mean_squared_error: 0.0117
# Epoch 42: val_loss improved from 0.00013 to 0.00012, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 1.3802e-04 - root_mean_squared_error: 0.0117 - val_loss: 1.2410e-04 - val_root_mean_squared_error: 0.0111
# Epoch 43/1000
# 630/654 [===========================>..] - ETA: 0s - loss: 1.3191e-04 - root_mean_squared_error: 0.0115
# Epoch 43: val_loss improved from 0.00012 to 0.00012, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 8ms/step - loss: 1.3107e-04 - root_mean_squared_error: 0.0114 - val_loss: 1.1539e-04 - val_root_mean_squared_error: 0.0107
# Epoch 44/1000
# 642/654 [============================>.] - ETA: 0s - loss: 1.2427e-04 - root_mean_squared_error: 0.0111
# Epoch 44: val_loss improved from 0.00012 to 0.00011, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.2416e-04 - root_mean_squared_error: 0.0111 - val_loss: 1.1489e-04 - val_root_mean_squared_error: 0.0107
# Epoch 45/1000
# 651/654 [============================>.] - ETA: 0s - loss: 1.1971e-04 - root_mean_squared_error: 0.0109
# Epoch 45: val_loss improved from 0.00011 to 0.00011, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.2042e-04 - root_mean_squared_error: 0.0110 - val_loss: 1.0715e-04 - val_root_mean_squared_error: 0.0104
# Epoch 46/1000
# 626/654 [===========================>..] - ETA: 0s - loss: 1.1548e-04 - root_mean_squared_error: 0.0107
# Epoch 46: val_loss improved from 0.00011 to 0.00010, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 1.1645e-04 - root_mean_squared_error: 0.0108 - val_loss: 1.0171e-04 - val_root_mean_squared_error: 0.0101
# Epoch 47/1000
# 643/654 [============================>.] - ETA: 0s - loss: 1.1051e-04 - root_mean_squared_error: 0.0105
# Epoch 47: val_loss did not improve from 0.00010
# 654/654 [==============================] - 2s 4ms/step - loss: 1.0988e-04 - root_mean_squared_error: 0.0105 - val_loss: 1.0636e-04 - val_root_mean_squared_error: 0.0103
# Epoch 48/1000
# 638/654 [============================>.] - ETA: 0s - loss: 1.0732e-04 - root_mean_squared_error: 0.0104
# Epoch 48: val_loss improved from 0.00010 to 0.00010, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.0746e-04 - root_mean_squared_error: 0.0104 - val_loss: 9.6691e-05 - val_root_mean_squared_error: 0.0098
# Epoch 49/1000
# 634/654 [============================>.] - ETA: 0s - loss: 1.0739e-04 - root_mean_squared_error: 0.0104
# Epoch 49: val_loss improved from 0.00010 to 0.00010, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.0668e-04 - root_mean_squared_error: 0.0103 - val_loss: 9.5058e-05 - val_root_mean_squared_error: 0.0097
# Epoch 50/1000
# 636/654 [============================>.] - ETA: 0s - loss: 1.0301e-04 - root_mean_squared_error: 0.0101
# Epoch 50: val_loss improved from 0.00010 to 0.00009, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 1.0238e-04 - root_mean_squared_error: 0.0101 - val_loss: 9.4499e-05 - val_root_mean_squared_error: 0.0097
# Epoch 51/1000
# 651/654 [============================>.] - ETA: 0s - loss: 1.0130e-04 - root_mean_squared_error: 0.0101
# Epoch 51: val_loss improved from 0.00009 to 0.00009, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 8s 12ms/step - loss: 1.0103e-04 - root_mean_squared_error: 0.0101 - val_loss: 8.7697e-05 - val_root_mean_squared_error: 0.0094
# Epoch 52/1000
# 646/654 [============================>.] - ETA: 0s - loss: 9.8632e-05 - root_mean_squared_error: 0.0099
# Epoch 52: val_loss did not improve from 0.00009
# 654/654 [==============================] - 3s 5ms/step - loss: 9.8514e-05 - root_mean_squared_error: 0.0099 - val_loss: 8.9459e-05 - val_root_mean_squared_error: 0.0095
# Epoch 53/1000
# 654/654 [==============================] - ETA: 0s - loss: 9.6199e-05 - root_mean_squared_error: 0.0098
# Epoch 53: val_loss improved from 0.00009 to 0.00009, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 9.6199e-05 - root_mean_squared_error: 0.0098 - val_loss: 8.5209e-05 - val_root_mean_squared_error: 0.0092
# Epoch 54/1000
# 651/654 [============================>.] - ETA: 0s - loss: 9.6205e-05 - root_mean_squared_error: 0.0098
# Epoch 54: val_loss improved from 0.00009 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 9.6121e-05 - root_mean_squared_error: 0.0098 - val_loss: 8.4209e-05 - val_root_mean_squared_error: 0.0092
# Epoch 55/1000
# 629/654 [===========================>..] - ETA: 0s - loss: 9.3378e-05 - root_mean_squared_error: 0.0097
# Epoch 55: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.4622e-05 - root_mean_squared_error: 0.0097 - val_loss: 8.4443e-05 - val_root_mean_squared_error: 0.0092
# Epoch 56/1000
# 647/654 [============================>.] - ETA: 0s - loss: 9.2973e-05 - root_mean_squared_error: 0.0096
# Epoch 56: val_loss did not improve from 0.00008
# 654/654 [==============================] - 4s 5ms/step - loss: 9.3821e-05 - root_mean_squared_error: 0.0097 - val_loss: 8.8979e-05 - val_root_mean_squared_error: 0.0094
# Epoch 57/1000
# 647/654 [============================>.] - ETA: 0s - loss: 9.2811e-05 - root_mean_squared_error: 0.0096
# Epoch 57: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 9.2847e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.3285e-05 - val_root_mean_squared_error: 0.0091
# Epoch 58/1000
# 639/654 [============================>.] - ETA: 0s - loss: 9.3202e-05 - root_mean_squared_error: 0.0097
# Epoch 58: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 9.3290e-05 - root_mean_squared_error: 0.0097 - val_loss: 8.1725e-05 - val_root_mean_squared_error: 0.0090
# Epoch 59/1000
# 647/654 [============================>.] - ETA: 0s - loss: 9.2782e-05 - root_mean_squared_error: 0.0096
# Epoch 59: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 9.2380e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.1102e-05 - val_root_mean_squared_error: 0.0090
# Epoch 60/1000
# 636/654 [============================>.] - ETA: 0s - loss: 9.2114e-05 - root_mean_squared_error: 0.0096
# Epoch 60: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.1885e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.1731e-05 - val_root_mean_squared_error: 0.0090
# Epoch 61/1000
# 623/654 [===========================>..] - ETA: 0s - loss: 9.3408e-05 - root_mean_squared_error: 0.0097
# Epoch 61: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 9.1714e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.0321e-05 - val_root_mean_squared_error: 0.0090
# Epoch 62/1000
# 631/654 [===========================>..] - ETA: 0s - loss: 9.2810e-05 - root_mean_squared_error: 0.0096
# Epoch 62: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.2104e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.1476e-05 - val_root_mean_squared_error: 0.0090
# Epoch 63/1000
# 637/654 [============================>.] - ETA: 0s - loss: 9.1955e-05 - root_mean_squared_error: 0.0096
# Epoch 63: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 9.2181e-05 - root_mean_squared_error: 0.0096 - val_loss: 8.2665e-05 - val_root_mean_squared_error: 0.0091
# Epoch 64/1000
# 654/654 [==============================] - ETA: 0s - loss: 9.0943e-05 - root_mean_squared_error: 0.0095
# Epoch 64: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 9.0943e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9983e-05 - val_root_mean_squared_error: 0.0089
# Epoch 65/1000
# 640/654 [============================>.] - ETA: 0s - loss: 9.1882e-05 - root_mean_squared_error: 0.0096
# Epoch 65: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.0809e-05 - root_mean_squared_error: 0.0095 - val_loss: 8.0694e-05 - val_root_mean_squared_error: 0.0090
# Epoch 66/1000
# 651/654 [============================>.] - ETA: 0s - loss: 9.0556e-05 - root_mean_squared_error: 0.0095
# Epoch 66: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 9.0555e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9857e-05 - val_root_mean_squared_error: 0.0089
# Epoch 67/1000
# 637/654 [============================>.] - ETA: 0s - loss: 9.1322e-05 - root_mean_squared_error: 0.0096
# Epoch 67: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.0459e-05 - root_mean_squared_error: 0.0095 - val_loss: 8.0072e-05 - val_root_mean_squared_error: 0.0089
# Epoch 68/1000
# 625/654 [===========================>..] - ETA: 0s - loss: 9.0665e-05 - root_mean_squared_error: 0.0095
# Epoch 68: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 9.0165e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9392e-05 - val_root_mean_squared_error: 0.0089
# Epoch 69/1000
# 639/654 [============================>.] - ETA: 0s - loss: 9.1431e-05 - root_mean_squared_error: 0.0096
# Epoch 69: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.0606e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9548e-05 - val_root_mean_squared_error: 0.0089
# Epoch 70/1000
# 646/654 [============================>.] - ETA: 0s - loss: 9.0569e-05 - root_mean_squared_error: 0.0095
# Epoch 70: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 7s 11ms/step - loss: 9.0026e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9346e-05 - val_root_mean_squared_error: 0.0089
# Epoch 71/1000
# 639/654 [============================>.] - ETA: 0s - loss: 9.0344e-05 - root_mean_squared_error: 0.0095
# Epoch 71: val_loss did not improve from 0.00008
# 654/654 [==============================] - 3s 4ms/step - loss: 9.0218e-05 - root_mean_squared_error: 0.0095 - val_loss: 8.0868e-05 - val_root_mean_squared_error: 0.0090
# Epoch 72/1000
# 649/654 [============================>.] - ETA: 0s - loss: 8.9715e-05 - root_mean_squared_error: 0.0095
# Epoch 72: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.9879e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9552e-05 - val_root_mean_squared_error: 0.0089
# Epoch 73/1000
# 653/654 [============================>.] - ETA: 0s - loss: 8.9980e-05 - root_mean_squared_error: 0.0095
# Epoch 73: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9916e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9589e-05 - val_root_mean_squared_error: 0.0089
# Epoch 74/1000
# 640/654 [============================>.] - ETA: 0s - loss: 8.9935e-05 - root_mean_squared_error: 0.0095
# Epoch 74: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.9759e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9274e-05 - val_root_mean_squared_error: 0.0089
# Epoch 75/1000
# 637/654 [============================>.] - ETA: 0s - loss: 8.9934e-05 - root_mean_squared_error: 0.0095
# Epoch 75: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.9548e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9615e-05 - val_root_mean_squared_error: 0.0089
# Epoch 76/1000
# 627/654 [===========================>..] - ETA: 0s - loss: 9.0331e-05 - root_mean_squared_error: 0.0095
# Epoch 76: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.0124e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9277e-05 - val_root_mean_squared_error: 0.0089
# Epoch 77/1000
# 652/654 [============================>.] - ETA: 0s - loss: 8.9470e-05 - root_mean_squared_error: 0.0095
# Epoch 77: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.9548e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9495e-05 - val_root_mean_squared_error: 0.0089
# Epoch 78/1000
# 645/654 [============================>.] - ETA: 0s - loss: 9.0585e-05 - root_mean_squared_error: 0.0095
# Epoch 78: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 6s 9ms/step - loss: 9.0127e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.8998e-05 - val_root_mean_squared_error: 0.0089
# Epoch 79/1000
# 627/654 [===========================>..] - ETA: 0s - loss: 9.0423e-05 - root_mean_squared_error: 0.0095
# Epoch 79: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9995e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9150e-05 - val_root_mean_squared_error: 0.0089
# Epoch 80/1000
# 628/654 [===========================>..] - ETA: 0s - loss: 9.0307e-05 - root_mean_squared_error: 0.0095
# Epoch 80: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.9299e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.9237e-05 - val_root_mean_squared_error: 0.0089
# Epoch 81/1000
# 654/654 [==============================] - ETA: 0s - loss: 8.9703e-05 - root_mean_squared_error: 0.0095
# Epoch 81: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9703e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9019e-05 - val_root_mean_squared_error: 0.0089
# Epoch 82/1000
# 648/654 [============================>.] - ETA: 0s - loss: 8.9500e-05 - root_mean_squared_error: 0.0095
# Epoch 82: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9171e-05 - root_mean_squared_error: 0.0094 - val_loss: 8.0216e-05 - val_root_mean_squared_error: 0.0090
# Epoch 83/1000
# 653/654 [============================>.] - ETA: 0s - loss: 8.9260e-05 - root_mean_squared_error: 0.0094
# Epoch 83: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9248e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.9235e-05 - val_root_mean_squared_error: 0.0089
# Epoch 84/1000
# 633/654 [============================>.] - ETA: 0s - loss: 7.8888e-05 - root_mean_squared_error: 0.0089
# Epoch 84: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9098e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.9041e-05 - val_root_mean_squared_error: 0.0089
# Epoch 85/1000
# 643/654 [============================>.] - ETA: 0s - loss: 8.9567e-05 - root_mean_squared_error: 0.0095
# Epoch 85: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.9118e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8863e-05 - val_root_mean_squared_error: 0.0089
# Epoch 86/1000
# 643/654 [============================>.] - ETA: 0s - loss: 8.9040e-05 - root_mean_squared_error: 0.0094
# Epoch 86: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9057e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.9151e-05 - val_root_mean_squared_error: 0.0089
# Epoch 87/1000
# 650/654 [============================>.] - ETA: 0s - loss: 8.9623e-05 - root_mean_squared_error: 0.0095
# Epoch 87: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9315e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9138e-05 - val_root_mean_squared_error: 0.0089
# Epoch 88/1000
# 632/654 [===========================>..] - ETA: 0s - loss: 9.0198e-05 - root_mean_squared_error: 0.0095
# Epoch 88: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.9245e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8889e-05 - val_root_mean_squared_error: 0.0089
# Epoch 89/1000
# 651/654 [============================>.] - ETA: 0s - loss: 9.0472e-05 - root_mean_squared_error: 0.0095
# Epoch 89: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 9.0284e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.9215e-05 - val_root_mean_squared_error: 0.0089
# Epoch 90/1000
# 629/654 [===========================>..] - ETA: 0s - loss: 9.0290e-05 - root_mean_squared_error: 0.0095
# Epoch 90: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9036e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8959e-05 - val_root_mean_squared_error: 0.0089
# Epoch 91/1000
# 625/654 [===========================>..] - ETA: 0s - loss: 8.9283e-05 - root_mean_squared_error: 0.0094
# Epoch 91: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.9341e-05 - root_mean_squared_error: 0.0095 - val_loss: 7.8657e-05 - val_root_mean_squared_error: 0.0089
# Epoch 92/1000
# 648/654 [============================>.] - ETA: 0s - loss: 8.9414e-05 - root_mean_squared_error: 0.0095
# Epoch 92: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9140e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8662e-05 - val_root_mean_squared_error: 0.0089
# Epoch 93/1000
# 645/654 [============================>.] - ETA: 0s - loss: 8.9507e-05 - root_mean_squared_error: 0.0095
# Epoch 93: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9069e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.9116e-05 - val_root_mean_squared_error: 0.0089
# Epoch 94/1000
# 644/654 [============================>.] - ETA: 0s - loss: 8.9531e-05 - root_mean_squared_error: 0.0095
# Epoch 94: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.8779e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8645e-05 - val_root_mean_squared_error: 0.0089
# Epoch 95/1000
# 650/654 [============================>.] - ETA: 0s - loss: 8.9223e-05 - root_mean_squared_error: 0.0094
# Epoch 95: val_loss did not improve from 0.00008
# 654/654 [==============================] - 3s 5ms/step - loss: 8.9053e-05 - root_mean_squared_error: 0.0094 - val_loss: 8.5672e-05 - val_root_mean_squared_error: 0.0093
# Epoch 96/1000
# 638/654 [============================>.] - ETA: 0s - loss: 9.0078e-05 - root_mean_squared_error: 0.0095
# Epoch 96: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9180e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8820e-05 - val_root_mean_squared_error: 0.0089
# Epoch 97/1000
# 631/654 [===========================>..] - ETA: 0s - loss: 8.9927e-05 - root_mean_squared_error: 0.0095
# Epoch 97: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.8825e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8775e-05 - val_root_mean_squared_error: 0.0089
# Epoch 98/1000
# 627/654 [===========================>..] - ETA: 0s - loss: 8.9491e-05 - root_mean_squared_error: 0.0095
# Epoch 98: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 8.8759e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8482e-05 - val_root_mean_squared_error: 0.0089
# Epoch 99/1000
# 650/654 [============================>.] - ETA: 0s - loss: 8.8970e-05 - root_mean_squared_error: 0.0094
# Epoch 99: val_loss did not improve from 0.00008
# 654/654 [==============================] - 3s 4ms/step - loss: 8.8841e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8596e-05 - val_root_mean_squared_error: 0.0089
# Epoch 100/1000
# 634/654 [============================>.] - ETA: 0s - loss: 9.0127e-05 - root_mean_squared_error: 0.0095
# Epoch 100: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.9254e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8431e-05 - val_root_mean_squared_error: 0.0089
# Epoch 101/1000
# 631/654 [===========================>..] - ETA: 0s - loss: 8.9792e-05 - root_mean_squared_error: 0.0095
# Epoch 101: val_loss did not improve from 0.00008
# 654/654 [==============================] - 3s 4ms/step - loss: 8.8650e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8572e-05 - val_root_mean_squared_error: 0.0089
# Epoch 102/1000
# 630/654 [===========================>..] - ETA: 0s - loss: 8.9521e-05 - root_mean_squared_error: 0.0095
# Epoch 102: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.8683e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8449e-05 - val_root_mean_squared_error: 0.0089
# Epoch 103/1000
# 643/654 [============================>.] - ETA: 0s - loss: 8.9779e-05 - root_mean_squared_error: 0.0095
# Epoch 103: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.8902e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8767e-05 - val_root_mean_squared_error: 0.0089
# Epoch 104/1000
# 646/654 [============================>.] - ETA: 0s - loss: 8.9077e-05 - root_mean_squared_error: 0.0094
# Epoch 104: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.9035e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8708e-05 - val_root_mean_squared_error: 0.0089
# Epoch 105/1000
# 649/654 [============================>.] - ETA: 0s - loss: 8.8888e-05 - root_mean_squared_error: 0.0094
# Epoch 105: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.8721e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.9280e-05 - val_root_mean_squared_error: 0.0089
# Epoch 106/1000
# 631/654 [===========================>..] - ETA: 0s - loss: 8.7245e-05 - root_mean_squared_error: 0.0093
# Epoch 106: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.8566e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8406e-05 - val_root_mean_squared_error: 0.0089
# Epoch 107/1000
# 638/654 [============================>.] - ETA: 0s - loss: 7.7680e-05 - root_mean_squared_error: 0.0088
# Epoch 107: val_loss did not improve from 0.00008
# 654/654 [==============================] - 3s 4ms/step - loss: 8.8563e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8451e-05 - val_root_mean_squared_error: 0.0089
# Epoch 108/1000
# 625/654 [===========================>..] - ETA: 0s - loss: 8.9046e-05 - root_mean_squared_error: 0.0094
# Epoch 108: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.8537e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8483e-05 - val_root_mean_squared_error: 0.0089
# Epoch 109/1000
# 645/654 [============================>.] - ETA: 0s - loss: 8.9081e-05 - root_mean_squared_error: 0.0094
# Epoch 109: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 8ms/step - loss: 8.8658e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8391e-05 - val_root_mean_squared_error: 0.0089
# Epoch 110/1000
# 654/654 [==============================] - ETA: 0s - loss: 8.8443e-05 - root_mean_squared_error: 0.0094
# Epoch 110: val_loss improved from 0.00008 to 0.00008, saving model to model_spot/forecasting-TRY\
# INFO:tensorflow:Assets written to: model_spot/forecasting-TRY\assets
# 654/654 [==============================] - 5s 7ms/step - loss: 8.8443e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8340e-05 - val_root_mean_squared_error: 0.0089
# Epoch 111/1000
# 641/654 [============================>.] - ETA: 0s - loss: 8.9245e-05 - root_mean_squared_error: 0.0094
# Epoch 111: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.8691e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8483e-05 - val_root_mean_squared_error: 0.0089
# Epoch 112/1000
# 635/654 [============================>.] - ETA: 0s - loss: 8.9357e-05 - root_mean_squared_error: 0.0095
# Epoch 112: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 3ms/step - loss: 8.8521e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8347e-05 - val_root_mean_squared_error: 0.0089
# Epoch 113/1000
# 652/654 [============================>.] - ETA: 0s - loss: 8.9050e-05 - root_mean_squared_error: 0.0094
# Epoch 113: val_loss did not improve from 0.00008
# 654/654 [==============================] - 2s 4ms/step - loss: 8.8846e-05 - root_mean_squared_error: 0.0094 - val_loss: 7.8380e-05 - val_root_mean_squared_error: 0.0089
# Epoch 114/1000
# 514/654 [======================>.......] - ETA: 0s - loss: 9.1510e-05 - root_mean_squared_error: 0.0096

# %%
# Evaluate the model on test data

test_loss, test_rmse = model.evaluate([input_1_test, input_2_test], output_test)
print(f"Test loss: {test_loss}, Test RMSE: {test_rmse}")

# %%
#Plot the training and validation loss

plt.figure(figsize=(10,5))
plt.plot(history.history['loss'][1:])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Assuming you have already defined 'history' somewhere in your code

plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss (log10 scale)')
plt.xlabel('Epoch')
plt.yscale('log')  # Set the y-axis to a logarithmic scale
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history["root_mean_squared_error"][1:])
plt.plot(history.history["val_root_mean_squared_error"][1:])
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
